# %% [markdown]
# # Import libraries needed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')
import statsmodels.api as sm
import itertools
import seaborn as sns

# %% [markdown]
# # Import the dataset

# %%
df = pd.read_excel('https://github.com/fazexplorer182/RIO-125-Forecasting-System---Project-Demand-of-Products-at-a-Retail-Outlet-Based-on-Historical-Data/blob/main/Dataset/superstoresales.xls?raw=true',parse_dates=['Order Date'])

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0       1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1       2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2       3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3       4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4       5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
#
# [5 rows x 21 columns]

# %%
#Check for missing values
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#Check the different types of product categories included
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
#Now we create a dataframe which includes only data related to furniture sales. 
furniture = df.loc[df['Category'] == 'Furniture']
furniture
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0          1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1          2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 3          4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 5          6  CA-2014-115812 2014-06-09  ...        7     0.00   14.1694
# 10        11  CA-2014-115812 2014-06-09  ...        9     0.20   85.3092
# ...      ...             ...        ...  ...      ...      ...       ...
# 9962    9963  CA-2015-168088 2015-03-19  ...        4     0.32  -67.6704
# 9964    9965  CA-2016-146374 2016-12-05  ...        1     0.00    6.4320
# 9980    9981  US-2015-151435 2015-09-06  ...        1     0.00   22.3548
# 9989    9990  CA-2014-110422 2014-01-21  ...        3     0.20    4.1028
# 9990    9991  CA-2017-121258 2017-02-26  ...        2     0.00   15.6332
#
# [2121 rows x 21 columns]

# %%
#Know the earliest date recorded
furniture['Order Date'].min()
# Out:
# Timestamp('2014-01-06 00:00:00')

# %%
#Know the most recent date recorded
furniture['Order Date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %% [markdown]
# # Data Processing

# %%
#Now we can remove unnecessary columns from the furniture dataframe
cols = ['Row ID','Order ID','Ship Date','Ship Mode','Customer ID','Customer Name','Segment','Country','City','State','Postal Code','Region','Product ID','Category','Sub-Category','Product Name','Quantity','Discount','Profit']
furniture.drop(cols,axis=1,inplace=True)
furniture
# Out:
#      Order Date      Sales
# 0    2016-11-08   261.9600
# 1    2016-11-08   731.9400
# 3    2015-10-11   957.5775
# 5    2014-06-09    48.8600
# 10   2014-06-09  1706.1840
# ...         ...        ...
# 9962 2015-03-19   383.4656
# 9964 2016-12-05    13.4000
# 9980 2015-09-06    85.9800
# 9989 2014-01-21    25.2480
# 9990 2017-02-26    91.9600
#
# [2121 rows x 2 columns]

# %%
#Now let's sort furniture datframe according to order date
furniture = furniture.sort_values('Order Date')
furniture
# Out:
#      Order Date     Sales
# 7474 2014-01-06  2573.820
# 7660 2014-01-07    76.728
# 866  2014-01-10    51.940
# 716  2014-01-11     9.940
# 2978 2014-01-13   545.940
# ...         ...       ...
# 7636 2017-12-29   258.750
# 7632 2017-12-29  1207.840
# 5131 2017-12-29   101.120
# 7635 2017-12-29   300.980
# 906  2017-12-30   323.136
#
# [2121 rows x 2 columns]

# %%
#Now let's find how much total furniture sales occurred on each date
furniture = furniture.groupby('Order Date')['Sales'].sum().reset_index()

# %%
furniture
# Out:
#     Order Date      Sales
# 0   2014-01-06  2573.8200
# 1   2014-01-07    76.7280
# 2   2014-01-10    51.9400
# 3   2014-01-11     9.9400
# 4   2014-01-13   879.9390
# ..         ...        ...
# 884 2017-12-24  1393.4940
# 885 2017-12-25   832.4540
# 886 2017-12-28   551.2568
# 887 2017-12-29  2330.7180
# 888 2017-12-30   323.1360
#
# [889 rows x 2 columns]

# %%
#Now let's set the Order date column as the index column
furniture = furniture.set_index('Order Date')
furniture
# Out:
#                 Sales
# Order Date
# 2014-01-06  2573.8200
# 2014-01-07    76.7280
# 2014-01-10    51.9400
# 2014-01-11     9.9400
# 2014-01-13   879.9390
# ...               ...
# 2017-12-24  1393.4940
# 2017-12-25   832.4540
# 2017-12-28   551.2568
# 2017-12-29  2330.7180
# 2017-12-30   323.1360
#
# [889 rows x 1 columns]

# %%
#Now let's see whether there is any frequency in the dataframe
furniture.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-07', '2014-01-10', '2014-01-11',
#                '2014-01-13', '2014-01-14', '2014-01-16', '2014-01-19',
#                '2014-01-20', '2014-01-21',
#                ...
#                '2017-12-18', '2017-12-19', '2017-12-21', '2017-12-22',
#                '2017-12-23', '2017-12-24', '2017-12-25', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=889, freq=None)

# %%
#Now let's resample the data into means of monthly sales of furniture and save this into a new variable called Order date
y_furniture = furniture['Sales'].resample('MS').mean()
y_furniture
# Out:
# Order Date
# 2014-01-01     480.194231
# 2014-02-01     367.931600
# 2014-03-01     857.291529
# 2014-04-01     567.488357
# 2014-05-01     432.049188
# 2014-06-01     695.059242
# 2014-07-01     601.169500
# 2014-08-01     457.521656
# 2014-09-01     992.353367
# 2014-10-01     769.015437
# 2014-11-01     980.221486
# 2014-12-01    1532.298325
# 2015-01-01     978.328467
# 2015-02-01     522.395667
# 2015-03-01     781.236437
# 2015-04-01     805.822962
# 2015-05-01     624.996700
# 2015-06-01     428.565500
# 2015-07-01     719.706316
# 2015-08-01     602.412012
# 2015-09-01    1382.790684
# 2015-10-01     632.980184
# 2015-11-01    1286.701354
# 2015-12-01    1049.355418
# 2016-01-01     508.182867
# 2016-02-01     356.868273
# 2016-03-01     609.575810
# 2016-04-01     695.373158
# 2016-05-01     687.265227
# 2016-06-01     816.910750
# 2016-07-01     768.736412
# 2016-08-01     734.307782
# 2016-09-01    1135.953371
# 2016-10-01     624.872474
# 2016-11-01    1271.345152
# 2016-12-01    1410.719808
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %%
#Now let's check the monthly sales value happened in year 2017
print(y_furniture['2017':])
# Out:
# Order Date
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %%
office= df.loc[df['Category'] == 'Office Supplies']
office
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount   Profit
# 2          3  CA-2016-138688 2016-06-12  ...        2      0.0   6.8714
# 4          5  US-2015-108966 2015-10-11  ...        2      0.2   2.5164
# 6          7  CA-2014-115812 2014-06-09  ...        4      0.0   1.9656
# 8          9  CA-2014-115812 2014-06-09  ...        3      0.2   5.7825
# 9         10  CA-2014-115812 2014-06-09  ...        5      0.0  34.4700
# ...      ...             ...        ...  ...      ...      ...      ...
# 9982    9983  US-2016-157728 2016-09-22  ...        7      0.0  16.7132
# 9984    9985  CA-2015-100251 2015-05-17  ...       10      0.0  15.1200
# 9985    9986  CA-2015-100251 2015-05-17  ...        4      0.0  16.1240
# 9992    9993  CA-2017-121258 2017-02-26  ...        4      0.0  13.3200
# 9993    9994  CA-2017-119914 2017-05-04  ...        2      0.0  72.9480
#
# [6026 rows x 21 columns]

# %%
office['Order Date'].min()
# Out:
# Timestamp('2014-01-03 00:00:00')

# %%
office['Order Date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
office.drop(cols,axis=1,inplace=True)
office
# Out:
#      Order Date    Sales
# 2    2016-06-12   14.620
# 4    2015-10-11   22.368
# 6    2014-06-09    7.280
# 8    2014-06-09   18.504
# 9    2014-06-09  114.900
# ...         ...      ...
# 9982 2016-09-22   35.560
# 9984 2015-05-17   31.500
# 9985 2015-05-17   55.600
# 9992 2017-02-26   29.600
# 9993 2017-05-04  243.160
#
# [6026 rows x 2 columns]

# %%
office= office.sort_values('Order Date')
office
# Out:
#      Order Date    Sales
# 7980 2014-01-03   16.448
# 740  2014-01-04  272.736
# 739  2014-01-04   11.784
# 741  2014-01-04    3.540
# 1759 2014-01-05   19.536
# ...         ...      ...
# 5091 2017-12-30    3.024
# 1297 2017-12-30   20.720
# 908  2017-12-30   52.776
# 1296 2017-12-30   13.904
# 645  2017-12-30  209.300
#
# [6026 rows x 2 columns]

# %%
office = office.groupby('Order Date')['Sales'].sum().reset_index()
office
# Out:
#      Order Date     Sales
# 0    2014-01-03    16.448
# 1    2014-01-04   288.060
# 2    2014-01-05    19.536
# 3    2014-01-06   685.340
# 4    2014-01-07    10.430
# ...         ...       ...
# 1143 2017-12-26   814.594
# 1144 2017-12-27    13.248
# 1145 2017-12-28  1091.244
# 1146 2017-12-29   282.440
# 1147 2017-12-30   299.724
#
# [1148 rows x 2 columns]

# %%
office = office.set_index('Order Date')
office
# Out:
#                Sales
# Order Date
# 2014-01-03    16.448
# 2014-01-04   288.060
# 2014-01-05    19.536
# 2014-01-06   685.340
# 2014-01-07    10.430
# ...              ...
# 2017-12-26   814.594
# 2017-12-27    13.248
# 2017-12-28  1091.244
# 2017-12-29   282.440
# 2017-12-30   299.724
#
# [1148 rows x 1 columns]

# %%
office.index
# Out:
# DatetimeIndex(['2014-01-03', '2014-01-04', '2014-01-05', '2014-01-06',
#                '2014-01-07', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-16', '2014-01-18',
#                ...
#                '2017-12-21', '2017-12-22', '2017-12-23', '2017-12-24',
#                '2017-12-25', '2017-12-26', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=1148, freq=None)

# %%
y_office = office['Sales'].resample('MS').mean()
y_office
# Out:
# Order Date
# 2014-01-01     285.357647
# 2014-02-01      63.042588
# 2014-03-01     391.176318
# 2014-04-01     464.794750
# 2014-05-01     324.346545
# 2014-06-01     588.774409
# 2014-07-01     756.060400
# 2014-08-01     541.879143
# 2014-09-01    1015.677704
# 2014-10-01     267.078815
# 2014-11-01     959.372714
# 2014-12-01     692.556231
# 2015-01-01     129.198571
# 2015-02-01     335.504187
# 2015-03-01     690.545522
# 2015-04-01     502.342320
# 2015-05-01     364.549440
# 2015-06-01     560.407737
# 2015-07-01     205.214739
# 2015-08-01     558.814667
# 2015-09-01     772.230680
# 2015-10-01     361.392083
# 2015-11-01     757.790357
# 2015-12-01     540.055800
# 2016-01-01     331.230125
# 2016-02-01     357.597368
# 2016-03-01     693.877240
# 2016-04-01     462.932478
# 2016-05-01     449.489724
# 2016-06-01     436.072400
# 2016-07-01     587.474727
# 2016-08-01     344.605385
# 2016-09-01     830.847786
# 2016-10-01     678.408083
# 2016-11-01     787.972231
# 2016-12-01    1357.055929
# 2017-01-01     967.013136
# 2017-02-01     389.882737
# 2017-03-01     538.899481
# 2017-04-01     558.229296
# 2017-05-01     508.776444
# 2017-06-01     650.463038
# 2017-07-01     393.902615
# 2017-08-01    1156.148154
# 2017-09-01    1139.137250
# 2017-10-01     886.045846
# 2017-11-01    1124.012036
# 2017-12-01    1049.549724
# Freq: MS, Name: Sales, dtype: float64

# %%
print(y_office['2017':])
# Out:
# Order Date
# 2017-01-01     967.013136
# 2017-02-01     389.882737
# 2017-03-01     538.899481
# 2017-04-01     558.229296
# 2017-05-01     508.776444
# 2017-06-01     650.463038
# 2017-07-01     393.902615
# 2017-08-01    1156.148154
# 2017-09-01    1139.137250
# 2017-10-01     886.045846
# 2017-11-01    1124.012036
# 2017-12-01    1049.549724
# Freq: MS, Name: Sales, dtype: float64

# %%
technology = df.loc[df['Category'] == 'Technology']
technology
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 7          8  CA-2014-115812 2014-06-09  ...        6      0.2   90.7152
# 11        12  CA-2014-115812 2014-06-09  ...        4      0.2   68.3568
# 19        20  CA-2014-143336 2014-08-27  ...        3      0.2   16.0110
# 26        27  CA-2016-121755 2016-01-16  ...        3      0.0   11.7741
# 35        36  CA-2016-117590 2016-12-08  ...        7      0.2  123.4737
# ...      ...             ...        ...  ...      ...      ...       ...
# 9983    9984  US-2016-157728 2016-09-22  ...        2      0.0   27.4344
# 9986    9987  CA-2016-125794 2016-09-29  ...        1      0.0   15.2208
# 9987    9988  CA-2017-163629 2017-11-17  ...        1      0.0   28.7964
# 9988    9989  CA-2017-163629 2017-11-17  ...        5      0.0   55.6470
# 9991    9992  CA-2017-121258 2017-02-26  ...        2      0.2   19.3932
#
# [1847 rows x 21 columns]

# %%
technology['Order Date'].min()
# Out:
# Timestamp('2014-01-06 00:00:00')

# %%
technology['Order Date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
technology.drop(cols,axis=1,inplace=True)
technology
# Out:
#      Order Date     Sales
# 7    2014-06-09   907.152
# 11   2014-06-09   911.424
# 19   2014-08-27   213.480
# 26   2016-01-16    90.570
# 35   2016-12-08  1097.544
# ...         ...       ...
# 9983 2016-09-22    97.980
# 9986 2016-09-29    36.240
# 9987 2017-11-17    79.990
# 9988 2017-11-17   206.100
# 9991 2017-02-26   258.576
#
# [1847 rows x 2 columns]

# %%
technology = technology.sort_values('Order Date')
technology
# Out:
#      Order Date    Sales
# 7478 2014-01-06  755.960
# 7477 2014-01-06  391.980
# 593  2014-01-09   31.200
# 765  2014-01-13  646.740
# 1913 2014-01-15  149.950
# ...         ...      ...
# 4924 2017-12-25   90.480
# 2569 2017-12-27  164.388
# 573  2017-12-28   14.850
# 1878 2017-12-29  302.376
# 907  2017-12-30   90.930
#
# [1847 rows x 2 columns]

# %%
technology = technology.groupby('Order Date')['Sales'].sum().reset_index()
technology
# Out:
#     Order Date     Sales
# 0   2014-01-06  1147.940
# 1   2014-01-09    31.200
# 2   2014-01-13   646.740
# 3   2014-01-15   149.950
# 4   2014-01-16   124.200
# ..         ...       ...
# 819 2017-12-25   401.208
# 820 2017-12-27   164.388
# 821 2017-12-28    14.850
# 822 2017-12-29   302.376
# 823 2017-12-30    90.930
#
# [824 rows x 2 columns]

# %%
technology = technology.set_index('Order Date')
technology
# Out:
#                Sales
# Order Date
# 2014-01-06  1147.940
# 2014-01-09    31.200
# 2014-01-13   646.740
# 2014-01-15   149.950
# 2014-01-16   124.200
# ...              ...
# 2017-12-25   401.208
# 2017-12-27   164.388
# 2017-12-28    14.850
# 2017-12-29   302.376
# 2017-12-30    90.930
#
# [824 rows x 1 columns]

# %%
technology.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-09', '2014-01-13', '2014-01-15',
#                '2014-01-16', '2014-01-20', '2014-01-26', '2014-02-01',
#                '2014-02-02', '2014-02-06',
#                ...
#                '2017-12-18', '2017-12-21', '2017-12-22', '2017-12-23',
#                '2017-12-24', '2017-12-25', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=824, freq=None)

# %%
y_technology = technology['Sales'].resample('MS').mean()
y_technology
# Out:
# Order Date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: Sales, dtype: float64

# %% [markdown]
# # Plotting the sales data for each categories

# %%
office.plot(figsize=(20,5))

# %%
furniture.plot(figsize=(20,5))

# %%
technology.plot(figsize=(20,5))

# %% [markdown]
# # Plotting the mean sales data for each categories

# %%
y_office.plot(figsize=(15,6))
plt.title("Office supplies sales")
plt.ylabel("Sales")
plt.show()

# %%
y_furniture.plot(figsize=(15,6))
plt.title("Furniture supplies sales")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
y_technology.plot(figsize=(15,6))
plt.title("Technology supplies sales")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ###### Boxplots on sales of each product categories

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(y_furniture).set_title('Box Plot on furniture sales')
# Out:
# Text(0.5, 1.0, 'Box Plot on furniture sales')

# %%
sns.boxplot(y_office).set_title('Box Plot office supply sales')
# Out:
# Text(0.5, 1.0, 'Box Plot office supply sales')

# %%
sns.boxplot(y_technology).set_title('Box Plot Technology sales')
# Out:
# Text(0.5, 1.0, 'Box Plot Technology sales')

# %% [markdown]
# # Perform ets decomposition

# %% [markdown]
# ###### ETS decomposition of office

# %%
from pylab import rcParams
rcParams['figure.figsize']=18,8
decomposition_office = sm.tsa.seasonal_decompose(y_office,model='additive')
fig = decomposition_office.plot()
plt.show()

# %%
decomposition_office.trend.plot(figsize=(18,5))

# %%
decomposition_office.seasonal.plot(figsize=(18,5))

# %% [markdown]
# ###### ETS decomposition of furniture

# %%
rcParams['figure.figsize']=18,8
decomposition_furniture = sm.tsa.seasonal_decompose(y_furniture,model='additive')
fig = decomposition_furniture.plot()
plt.show()

# %%
decomposition_furniture.seasonal.plot(figsize=(18,5))

# %%
decomposition_furniture.trend.plot(figsize=(18,5))

# %% [markdown]
# ###### ETS decomposition of technology

# %%
rcParams['figure.figsize']=18,8
decomposition_technology = sm.tsa.seasonal_decompose(y_technology,model='additive')
fig = decomposition_technology.plot()
plt.show()

# %%
decomposition_technology.trend.plot(figsize=(18,5))

# %%
decomposition_technology.seasonal.plot(figsize=(18,5))

# %% [markdown]
# # Test for stationarity

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %% [markdown]
# ##### Furniture

# %%
adf_test(y_furniture)
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic      -5.191070
# p-value                  0.000009
# # lags used             10.000000
# # observations          37.000000
# critical value (1%)     -3.620918
# critical value (5%)     -2.943539
# critical value (10%)    -2.610400
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# ##### Office

# %%
adf_test(y_office)
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic      -4.664633
# p-value                  0.000098
# # lags used              0.000000
# # observations          47.000000
# critical value (1%)     -3.577848
# critical value (5%)     -2.925338
# critical value (10%)    -2.600774
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# ##### Technology

# %%
adf_test(y_technology)
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -7.187969e+00
# p-value                 2.547334e-10
# # lags used             0.000000e+00
# # observations          4.700000e+01
# critical value (1%)    -3.577848e+00
# critical value (5%)    -2.925338e+00
# critical value (10%)   -2.600774e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# # Time series forecasting with ARIMA

# %% [markdown]
# ## Train test split

# %% [markdown]
# #### Office

# %%
len(y_office)
# Out:
# 48

# %%
48-12
# Out:
# 36

# %%
train_office = y_office.iloc[:36]
test_office = y_office.iloc[36:]

# %%
train_office
# Out:
# Order Date
# 2014-01-01     285.357647
# 2014-02-01      63.042588
# 2014-03-01     391.176318
# 2014-04-01     464.794750
# 2014-05-01     324.346545
# 2014-06-01     588.774409
# 2014-07-01     756.060400
# 2014-08-01     541.879143
# 2014-09-01    1015.677704
# 2014-10-01     267.078815
# 2014-11-01     959.372714
# 2014-12-01     692.556231
# 2015-01-01     129.198571
# 2015-02-01     335.504187
# 2015-03-01     690.545522
# 2015-04-01     502.342320
# 2015-05-01     364.549440
# 2015-06-01     560.407737
# 2015-07-01     205.214739
# 2015-08-01     558.814667
# 2015-09-01     772.230680
# 2015-10-01     361.392083
# 2015-11-01     757.790357
# 2015-12-01     540.055800
# 2016-01-01     331.230125
# 2016-02-01     357.597368
# 2016-03-01     693.877240
# 2016-04-01     462.932478
# 2016-05-01     449.489724
# 2016-06-01     436.072400
# 2016-07-01     587.474727
# 2016-08-01     344.605385
# 2016-09-01     830.847786
# 2016-10-01     678.408083
# 2016-11-01     787.972231
# 2016-12-01    1357.055929
# Freq: MS, Name: Sales, dtype: float64

# %%
test_office
# Out:
# Order Date
# 2017-01-01     967.013136
# 2017-02-01     389.882737
# 2017-03-01     538.899481
# 2017-04-01     558.229296
# 2017-05-01     508.776444
# 2017-06-01     650.463038
# 2017-07-01     393.902615
# 2017-08-01    1156.148154
# 2017-09-01    1139.137250
# 2017-10-01     886.045846
# 2017-11-01    1124.012036
# 2017-12-01    1049.549724
# Freq: MS, Name: Sales, dtype: float64

# %%
len(test_office)
# Out:
# 12

# %% [markdown]
# ###### Find the best Model

# %%
from pmdarima import auto_arima

# %%
model_office = auto_arima(y_office,m=12,seasonal=True,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=670.399, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=682.234, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=672.340, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=680.349, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=668.518, Time=0.63 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=668.772, Time=0.33 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=668.281, Time=1.27 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=1.53 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=669.752, Time=0.50 sec
#  ARIMA(3,1,2)(0,0,2)[12] intercept   : AIC=668.892, Time=1.37 sec
#  ARIMA(2,1,3)(0,0,2)[12] intercept   : AIC=inf, Time=1.46 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(1,1,3)(0,0,2)[12] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(3,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(3,1,3)(0,0,2)[12] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(2,1,2)(0,0,2)[12]             : AIC=inf, Time=0.97 sec
#
# Best model:  ARIMA(2,1,2)(0,0,2)[12] intercept
# Total fit time: 15.293 seconds

# %%
model_office.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   48
# Model:             SARIMAX(2, 1, 2)x(0, 0, 2, 12)   Log Likelihood                -326.141
# Date:                            Fri, 21 May 2021   AIC                            668.281
# Time:                                    18:55:08   BIC                            683.082
# Sample:                                         0   HQIC                           673.851
#                                              - 48
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      8.8234    123.588      0.071      0.943    -233.405     251.052
# ar.L1         -0.0013     15.943  -8.33e-05      1.000     -31.250      31.247
# ar.L2          0.0378      2.507      0.015      0.988      -4.876       4.952
# ma.L1         -0.8246     16.020     -0.051      0.959     -32.223      30.574
# ma.L2         -0.1556     15.726     -0.010      0.992     -30.978      30.666
# ma.S.L12       0.2035      0.289      0.703      0.482      -0.364       0.771
# ma.S.L24       0.2675      0.447      0.599      0.549      -0.608       1.143
# sigma2       6.34e+04    3.1e+04      2.044      0.041    2591.923    1.24e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 2.03
# Prob(Q):                              0.85   Prob(JB):                         0.36
# Heteroskedasticity (H):               1.16   Skew:                             0.51
# Prob(H) (two-sided):                  0.76   Kurtosis:                         3.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_office
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(2, 1, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args={}, seasonal_order=(0, 0, 2, 12),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)

# %% [markdown]
# ###### Train the model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_office = SARIMAX(train_office,order=(0, 1, 1),seasonal_order=(2, 0, 0, 12),enforce_invertibility=False)

# %%
result_office = model_office.fit()

# %%
result_office.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Sales   No. Observations:                   36
# Model:             SARIMAX(0, 1, 1)x(2, 0, [], 12)   Log Likelihood                -242.536
# Date:                             Fri, 21 May 2021   AIC                            493.072
# Time:                                     18:55:08   BIC                            499.294
# Sample:                                 01-01-2014   HQIC                           495.220
#                                       - 12-01-2016
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9292      0.151     -6.143      0.000      -1.226      -0.633
# ar.S.L12       0.3049      0.315      0.969      0.333      -0.312       0.922
# ar.S.L24       0.3410      0.504      0.677      0.499      -0.647       1.329
# sigma2      4.942e+04    1.6e+04      3.094      0.002    1.81e+04    8.07e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 7.89
# Prob(Q):                              0.68   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.98   Skew:                             0.74
# Prob(H) (two-sided):                  0.98   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ###### Run model diagnostics to investigate any unusual behaviour

# %%
result_office.plot_diagnostics(figsize=(16,8))
plt.show()

# %% [markdown]
# ###### Now predict values in the future

# %%
start = len(train_office)
end = len(train_office) + len(test_office) - 1

# %%
prediction_office = result_office.predict(start,end).rename('SARIMA model predictions')

# %%
prediction_office
# Out:
# 2017-01-01    408.624491
# 2017-02-01    487.009631
# 2017-03-01    710.608491
# 2017-04-01    576.016155
# 2017-05-01    524.933139
# 2017-06-01    587.624902
# 2017-07-01    512.678164
# 2017-08-01    559.191622
# 2017-09-01    780.226162
# 2017-10-01    593.658239
# 2017-11-01    762.228764
# 2017-12-01    861.511263
# Freq: MS, Name: SARIMA model predictions, dtype: float64

# %%
test_office.plot(figsize=(12,8),legend=True)
prediction_office.plot(legend=True)
plt.title("Office supplies sales")
# Out:
# Text(0.5, 1.0, 'Office supplies sales')

# %% [markdown]
# ###### Evaluation our model

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from statsmodels.tools.eval_measures import rmse

# %%
mean_squared_error(test_office,prediction_office)
# Out:
# 92188.29588739188

# %%
rmse(test_office,prediction_office)
# Out:
# 303.62525568106463

# %%
test_office.mean()
# Out:
# 780.1716465938612

# %%
#Comparing the mean value to the root mean square value we can say that the model had predicted in a good way

# %% [markdown]
# ###### Now let us forecast into the unknown future

# %%
model_office_final = SARIMAX(y_office,order=(0, 1, 1),seasonal_order=(2, 0, 0, 12),enforce_invertibility=False)

# %%
result_office_final = model_office_final.fit()

# %%
forecast_office = result_office_final.predict(len(y_office),len(y_office)+11,typ='levels').rename('SARIMA forecast')

# %%
y_office.plot(legend=True,figsize=(12,8))
forecast_office.plot(legend=True)
plt.title("Office supplies sales")
# Out:
# Text(0.5, 1.0, 'Office supplies sales')

# %%
pred_office = result_office_final.get_forecast(steps=24)
pred_ci_office = pred_office.conf_int()
ax = y_office.plot(label='observed',figsize=(14,7))
pred_office.predicted_mean.plot(ax=ax,label='Forecast')
ax.fill_between(pred_ci_office.index,
               pred_ci_office.iloc[:,0],
               pred_ci_office.iloc[:,1],color='k',alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Office supplies Sales')
plt.legend()
plt.show()

# %% [markdown]
# #### Furniture

# %%
len(y_furniture)
# Out:
# 48

# %%
train_furniture = y_furniture.iloc[:36]
test_furniture = y_furniture.iloc[36:]

# %%
train_furniture
# Out:
# Order Date
# 2014-01-01     480.194231
# 2014-02-01     367.931600
# 2014-03-01     857.291529
# 2014-04-01     567.488357
# 2014-05-01     432.049188
# 2014-06-01     695.059242
# 2014-07-01     601.169500
# 2014-08-01     457.521656
# 2014-09-01     992.353367
# 2014-10-01     769.015437
# 2014-11-01     980.221486
# 2014-12-01    1532.298325
# 2015-01-01     978.328467
# 2015-02-01     522.395667
# 2015-03-01     781.236437
# 2015-04-01     805.822962
# 2015-05-01     624.996700
# 2015-06-01     428.565500
# 2015-07-01     719.706316
# 2015-08-01     602.412012
# 2015-09-01    1382.790684
# 2015-10-01     632.980184
# 2015-11-01    1286.701354
# 2015-12-01    1049.355418
# 2016-01-01     508.182867
# 2016-02-01     356.868273
# 2016-03-01     609.575810
# 2016-04-01     695.373158
# 2016-05-01     687.265227
# 2016-06-01     816.910750
# 2016-07-01     768.736412
# 2016-08-01     734.307782
# 2016-09-01    1135.953371
# 2016-10-01     624.872474
# 2016-11-01    1271.345152
# 2016-12-01    1410.719808
# Freq: MS, Name: Sales, dtype: float64

# %%
test_furniture
# Out:
# Order Date
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %%
len(test_furniture)
# Out:
# 12

# %% [markdown]
# ###### Find the best model

# %%
model_furniture = auto_arima(y_furniture,seasonal=True,m=12,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=494.537, Time=1.37 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=497.083, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=494.685, Time=0.30 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=495.371, Time=0.02 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=496.163, Time=1.01 sec
#  ARIMA(2,0,2)(2,1,1)[12] intercept   : AIC=501.614, Time=2.09 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=500.301, Time=2.55 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=494.997, Time=2.08 sec
#  ARIMA(2,0,2)(2,1,0)[12] intercept   : AIC=inf, Time=2.06 sec
#  ARIMA(2,0,2)(2,1,2)[12] intercept   : AIC=503.540, Time=2.65 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=498.528, Time=1.06 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(3,0,2)(1,1,1)[12] intercept   : AIC=499.218, Time=1.29 sec
#  ARIMA(2,0,3)(1,1,1)[12] intercept   : AIC=inf, Time=1.21 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(1,0,3)(1,1,1)[12] intercept   : AIC=499.336, Time=1.07 sec
#  ARIMA(3,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(3,0,3)(1,1,1)[12] intercept   : AIC=inf, Time=1.44 sec
#  ARIMA(2,0,2)(1,1,1)[12]             : AIC=inf, Time=1.31 sec
#
# Best model:  ARIMA(2,0,2)(1,1,1)[12] intercept
# Total fit time: 27.001 seconds

# %%
model_furniture.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   48
# Model:             SARIMAX(2, 0, 2)x(1, 1, [1], 12)   Log Likelihood                -239.269
# Date:                              Fri, 21 May 2021   AIC                            494.537
# Time:                                      18:55:38   BIC                            507.205
# Sample:                                           0   HQIC                           498.959
#                                                - 48
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.1928      1.680     -0.115      0.909      -3.486       3.101
# ar.L1          1.7057      0.206      8.267      0.000       1.301       2.110
# ar.L2         -0.8533      0.181     -4.707      0.000      -1.209      -0.498
# ma.L1         -1.9393      1.963     -0.988      0.323      -5.787       1.908
# ma.L2          0.9500      1.832      0.519      0.604      -2.641       4.541
# ar.S.L12      -0.1207      0.565     -0.214      0.831      -1.227       0.986
# ma.S.L12      -0.8573      3.157     -0.272      0.786      -7.045       5.330
# sigma2      1.913e+04   7.02e+04      0.272      0.785   -1.18e+05    1.57e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.93   Jarque-Bera (JB):                 0.46
# Prob(Q):                              0.34   Prob(JB):                         0.80
# Heteroskedasticity (H):               0.45   Skew:                             0.04
# Prob(H) (two-sided):                  0.18   Kurtosis:                         2.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_furniture
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(2, 0, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args={}, seasonal_order=(1, 1, 1, 12),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)

# %% [markdown]
# ###### Train the model

# %%
model_furniture = SARIMAX(train_furniture,order=(2, 0, 2),seasonal_order=(1, 1, 1, 12),enforce_invertibility=False)

# %%
result_furniture = model_furniture.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %% [markdown]
# ###### Run model diagnostics to investigate any unusual behaviour

# %%
result_furniture.plot_diagnostics(figsize=(16,8))
plt.show()

# %% [markdown]
# ###### Now predict the values in the future

# %%
start = len(train_furniture)
end = len(train_furniture) + len(test_furniture) - 1

# %%
prediction_furniture = result_furniture.predict(start,end).rename('SARIMA model')

# %%
prediction_furniture
# Out:
# 2017-01-01     712.213681
# 2017-02-01     476.125503
# 2017-03-01     866.249606
# 2017-04-01     646.077349
# 2017-05-01     554.756292
# 2017-06-01     558.462577
# 2017-07-01     615.288334
# 2017-08-01     546.990104
# 2017-09-01    1258.629341
# 2017-10-01     641.723183
# 2017-11-01    1166.061901
# 2017-12-01    1248.192439
# Freq: MS, Name: SARIMA model, dtype: float64

# %%
test_furniture.plot(figsize=(12,8),legend=True)
prediction_furniture.plot(legend=True)
plt.title("Furniture item sales")
# Out:
# Text(0.5, 1.0, 'Furniture item sales')

# %%
#Evaluation of our model

# %%
mean_squared_error(test_furniture,prediction_furniture)
# Out:
# 41528.7870741509

# %%
rmse(test_furniture,prediction_furniture)
# Out:
# 203.78613072078997

# %%
test_furniture.mean()
# Out:
# 788.9924321352877

# %% [markdown]
# ###### Now let us forecast into the Unknown Future

# %%
model_furniture_final = SARIMAX(y_furniture,order=(2, 0, 2),seasonal_order=(1, 1, 1, 12),enforce_invertibility=False)

# %%
result_furniture_final = model_furniture_final.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
forecast_furniture = result_furniture_final.predict(len(y_furniture),len(y_furniture)+11,typ='levels').rename('SARIMA forecast')

# %%
y_furniture.plot(legend=True,figsize=(12,8))
forecast_furniture.plot(legend=True)

# %%
pred_furniture = result_furniture_final.get_forecast(steps=24)
pred_ci_furniture = pred_furniture.conf_int()
ax = y_furniture.plot(label='observed',figsize=(14,7))
pred_furniture.predicted_mean.plot(ax=ax,label='Forecast')
ax.fill_between(pred_ci_furniture.index,
               pred_ci_furniture.iloc[:,0],
               pred_ci_furniture.iloc[:,1],color='k',alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()

# %% [markdown]
# #### Technology

# %%
len(y_technology)
# Out:
# 48

# %%
train_technology = y_technology.iloc[:36]
test_technology = y_technology.iloc[36:]

# %%
train_technology
# Out:
# Order Date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# Freq: MS, Name: Sales, dtype: float64

# %%
test_technology
# Out:
# Order Date
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: Sales, dtype: float64

# %%
len(test_technology)
# Out:
# 12

# %% [markdown]
# ###### Find the best model

# %%
model_technology = auto_arima(y_technology,seasonal=True,m=12,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=732.020, Time=0.65 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=725.877, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=729.717, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=729.615, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=807.454, Time=0.01 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=727.873, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=727.843, Time=0.03 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=729.843, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=727.740, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=727.697, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=729.641, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[12] intercept
# Total fit time: 1.412 seconds

# %%
model_technology.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:                        SARIMAX   Log Likelihood                -360.939
# Date:                Fri, 21 May 2021   AIC                            725.877
# Time:                        18:55:43   BIC                            729.620
# Sample:                             0   HQIC                           727.291
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    967.6149     77.667     12.458      0.000     815.390    1119.840
# sigma2       1.99e+05   4.64e+04      4.292      0.000    1.08e+05     2.9e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 5.70
# Prob(Q):                              0.70   Prob(JB):                         0.06
# Heteroskedasticity (H):               0.69   Skew:                             0.84
# Prob(H) (two-sided):                  0.46   Kurtosis:                         3.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_technology
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(0, 0, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)

# %%
#That means our data have White noise .
#Time series that show no autocorrelation are called white noise.
#If a time series is white noise, it is a sequence of random numbers and cannot be predicted. If the series of forecast errors are not white noise, it suggests improvements could be made to the predictive model.
#https://machinelearningmastery.com/white-noise-time-series-python/
#https://machinelearningmastery.com/white-noise-time-series-python/#:~:text=White%20noise%20is%20an%20important,made%20to%20the%20predictive%20model.

# %%
model_technology = auto_arima(y_technology,allowmean=False,allowdrift=False,seasonal=True,m=12,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=732.020, Time=0.63 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=725.877, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=729.717, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=729.615, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=807.454, Time=0.01 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=727.873, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=727.843, Time=0.03 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=729.843, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=727.740, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=727.697, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=729.641, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[12] intercept
# Total fit time: 1.373 seconds

# %% [markdown]
# ###### Train the model

# %%
model_technology = SARIMAX(train_technology,order=(0, 0, 0),seasonal_order=(0, 0, 0, 12),enforce_invertibility=False)

# %%
result_technology = model_technology.fit()

# %% [markdown]
# ###### Run model diagnostics to investigate any unusual behaviour¶

# %%
result_technology.plot_diagnostics(figsize=(16,8))
plt.show()

# %% [markdown]
# ###### Now predict the future values

# %%
start = len(train_technology)
end = len(train_technology) + len(test_technology) - 1

# %%
prediction_technology = result_technology.predict(start,end).rename('SARIMA model')

# %%
prediction_technology
# Out:
# 2017-01-01    0.0
# 2017-02-01    0.0
# 2017-03-01    0.0
# 2017-04-01    0.0
# 2017-05-01    0.0
# 2017-06-01    0.0
# 2017-07-01    0.0
# 2017-08-01    0.0
# 2017-09-01    0.0
# 2017-10-01    0.0
# 2017-11-01    0.0
# 2017-12-01    0.0
# Freq: MS, Name: SARIMA model, dtype: float64

# %%
model_technology_final = SARIMAX(y_technology,order=(0, 0, 0),seasonal_order=(0, 0, 0, 12),enforce_invertibility=False)

# %%
result_technology_final = model_technology_final.fit()

# %%
forecast_technology = result_technology_final.predict(len(y_technology),len(y_technology)+11,typ='levels').rename('SARIMA forecast')

# %%
y_technology.plot(legend=True,figsize=(12,8))
forecast_technology.plot(legend=True)

# %% [markdown]
# # Comparing Other categories

# %%
furniture1 = pd.DataFrame({'Order Date': y_furniture.index , 'Sales':y_furniture.values})
furniture1
# Out:
#    Order Date        Sales
# 0  2014-01-01   480.194231
# 1  2014-02-01   367.931600
# 2  2014-03-01   857.291529
# 3  2014-04-01   567.488357
# 4  2014-05-01   432.049188
# 5  2014-06-01   695.059242
# 6  2014-07-01   601.169500
# 7  2014-08-01   457.521656
# 8  2014-09-01   992.353367
# 9  2014-10-01   769.015437
# 10 2014-11-01   980.221486
# 11 2014-12-01  1532.298325
# 12 2015-01-01   978.328467
# 13 2015-02-01   522.395667
# 14 2015-03-01   781.236437
# 15 2015-04-01   805.822962
# 16 2015-05-01   624.996700
# 17 2015-06-01   428.565500
# 18 2015-07-01   719.706316
# 19 2015-08-01   602.412012
# 20 2015-09-01  1382.790684
# 21 2015-10-01   632.980184
# 22 2015-11-01  1286.701354
# 23 2015-12-01  1049.355418
# 24 2016-01-01   508.182867
# 25 2016-02-01   356.868273
# 26 2016-03-01   609.575810
# 27 2016-04-01   695.373158
# 28 2016-05-01   687.265227
# 29 2016-06-01   816.910750
# 30 2016-07-01   768.736412
# 31 2016-08-01   734.307782
# 32 2016-09-01  1135.953371
# 33 2016-10-01   624.872474
# 34 2016-11-01  1271.345152
# 35 2016-12-01  1410.719808
# 36 2017-01-01   397.602133
# 37 2017-02-01   528.179800
# 38 2017-03-01   544.672240
# 39 2017-04-01   453.297905
# 40 2017-05-01   678.302328
# 41 2017-06-01   826.460291
# 42 2017-07-01   562.524857
# 43 2017-08-01   857.881889
# 44 2017-09-01  1209.508583
# 45 2017-10-01   875.362728
# 46 2017-11-01  1277.817759
# 47 2017-12-01  1256.298672

# %%
office1 = pd.DataFrame({'Order Date': y_office.index , 'Sales':y_office.values})
office1
# Out:
#    Order Date        Sales
# 0  2014-01-01   285.357647
# 1  2014-02-01    63.042588
# 2  2014-03-01   391.176318
# 3  2014-04-01   464.794750
# 4  2014-05-01   324.346545
# 42 2017-07-01       1054.996636       562.524857    393.902615
# 43 2017-08-01        978.842333       857.881889   1156.148154
# 44 2017-09-01       1077.704120      1209.508583   1139.137250
# 45 2017-10-01       1493.439227       875.362728    886.045846
# 46 2017-11-01       1996.750920      1277.817759   1124.012036
# 47 2017-12-01        955.865652      1256.298672   1049.549724

# %%
plt.figure(figsize=(20,8))
plt.plot(store_office_furniture['Order Date'],store_office_furniture['furniture_sales'],'b-',label='furniture')
plt.plot(store_office_furniture['Order Date'],store_office_furniture['office_sales'],'r-',label='office supplies')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales of furniture and office supplies')
plt.legend()

# %%
plt.figure(figsize=(20,8))
plt.plot(store_office_technology['Order Date'],store_office_technology['technology_sales'],'b-',label='technology')
plt.plot(store_office_technology['Order Date'],store_office_technology['office_sales'],'r-',label='office supplies')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales of technology and office supplies')
plt.legend()

# %%
plt.figure(figsize=(20,8))
plt.plot(store_technology_furniture['Order Date'],store_technology_furniture['furniture_sales'],'b-',label='furniture')
plt.plot(store_technology_furniture['Order Date'],store_technology_furniture['technology_sales'],'r-',label='technology supplies')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales of furniture and technology supplies')
plt.legend()

# %%
plt.figure(figsize=(20,8))
plt.plot(store_office_furniture_technology['Order Date'],store_office_furniture_technology['furniture_sales'],'b-',label='furniture')
plt.plot(store_office_furniture_technology['Order Date'],store_office_furniture_technology['office_sales'],'r-',label='office supplies')
plt.plot(store_office_furniture_technology['Order Date'],store_office_furniture_technology['technology_sales'],'g-',label='technology')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales of furniture,technology and office supplies')
plt.legend()

# %% [markdown]
# # Time series modelling with prophet

# %%
import pandas as pd
from fbprophet import Prophet
import matplotlib.pyplot as plt

# %% [markdown]
# ###### Furniture

# %%
y_furniture_df = y_furniture.to_frame()

# %%
y_furniture_df['ds'] = y_furniture_df.index

# %%
y_furniture_df.columns = ['y','ds']

# %%
y_furniture_df
# Out:
#                       y         ds
# Order Date
# 2014-01-01   480.194231 2014-01-01
# 2014-02-01   367.931600 2014-02-01
# 2014-03-01   857.291529 2014-03-01
# 2014-04-01   567.488357 2014-04-01
# 2014-05-01   432.049188 2014-05-01
# 2014-06-01   695.059242 2014-06-01
# 2014-07-01   601.169500 2014-07-01
# 2014-08-01   457.521656 2014-08-01
# 2014-09-01   992.353367 2014-09-01
# 2014-10-01   769.015437 2014-10-01
# 2014-11-01   980.221486 2014-11-01
# 2014-12-01  1532.298325 2014-12-01
# 2015-01-01   978.328467 2015-01-01
# 2015-02-01   522.395667 2015-02-01
# 2015-03-01   781.236437 2015-03-01
# 2015-04-01   805.822962 2015-04-01
# 2015-05-01   624.996700 2015-05-01
# 2015-06-01   428.565500 2015-06-01
# 2015-07-01   719.706316 2015-07-01
# 2015-08-01   602.412012 2015-08-01
# 2015-09-01  1382.790684 2015-09-01
# 2015-10-01   632.980184 2015-10-01
# 2015-11-01  1286.701354 2015-11-01
# 2015-12-01  1049.355418 2015-12-01
# 2016-01-01   508.182867 2016-01-01
# 2016-02-01   356.868273 2016-02-01
# 2016-03-01   609.575810 2016-03-01
# 2016-04-01   695.373158 2016-04-01
# 2016-05-01   687.265227 2016-05-01
# 2016-06-01   816.910750 2016-06-01
# 2016-07-01   768.736412 2016-07-01
# 2016-08-01   734.307782 2016-08-01
# 2016-09-01  1135.953371 2016-09-01
# 2016-10-01   624.872474 2016-10-01
# 2016-11-01  1271.345152 2016-11-01
# 2016-12-01  1410.719808 2016-12-01
# 2017-01-01   397.602133 2017-01-01
# 2017-02-01   528.179800 2017-02-01
# 2017-03-01   544.672240 2017-03-01
# 2017-04-01   453.297905 2017-04-01
# 2017-05-01   678.302328 2017-05-01
# 2017-06-01   826.460291 2017-06-01
# 2017-07-01   562.524857 2017-07-01
# 2017-08-01   857.881889 2017-08-01
# 2017-09-01  1209.508583 2017-09-01
# 2017-10-01   875.362728 2017-10-01
# 2017-11-01  1277.817759 2017-11-01
# 2017-12-01  1256.298672 2017-12-01

# %%
y_furniture_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2014-01-01 to 2017-12-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       48 non-null     float64
#  1   ds      48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.4 KB

# %%
m_furniture = Prophet()

# %%
m_furniture.fit(y_furniture_df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_furniture = m_furniture.make_future_dataframe(periods=24,freq='MS')

# %%
future_furniture
# Out:
#            ds
# 0  2014-01-01
# 1  2014-02-01
# 2  2014-03-01
# 3  2014-04-01
# 4  2014-05-01
# ..        ...
# 67 2019-08-01
# 68 2019-09-01
# 69 2019-10-01
# 70 2019-11-01
# 71 2019-12-01
#
# [72 rows x 1 columns]

# %%
forecast_furniture = m_furniture.predict(future_furniture)

# %%
forecast_furniture
# Out:
#            ds       trend  ...  multiplicative_terms_upper         yhat
# 0  2014-01-01  726.057713  ...                         0.0   535.372051
# 1  2014-02-01  727.494023  ...                         0.0   451.116320
# 2  2014-03-01  728.791335  ...                         0.0   706.401580
# 3  2014-04-01  730.227645  ...                         0.0   630.086487
# 4  2014-05-01  731.617622  ...                         0.0   570.801960
# ..        ...         ...  ...                         ...          ...
# 67 2019-08-01  820.483484  ...                         0.0   667.740901
# 68 2019-09-01  821.919793  ...                         0.0  1373.632835
# 69 2019-10-01  823.309770  ...                         0.0   809.517572
# 70 2019-11-01  824.746079  ...                         0.0  1237.890821
# 71 2019-12-01  826.136056  ...                         0.0  1243.501709
#
# [72 rows x 16 columns]

# %%
forecast_furniture.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast_furniture[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
# 2017-01-01   967.013136 2017-01-01
# 2017-02-01   389.882737 2017-02-01
# 2017-03-01   538.899481 2017-03-01
# 2017-04-01   558.229296 2017-04-01
# 2017-05-01   508.776444 2017-05-01
# 2017-06-01   650.463038 2017-06-01
# 2017-07-01   393.902615 2017-07-01
# 2017-08-01  1156.148154 2017-08-01
# 2017-09-01  1139.137250 2017-09-01
# 2017-10-01   886.045846 2017-10-01
# 2017-11-01  1124.012036 2017-11-01
# 2017-12-01  1049.549724 2017-12-01

# %%
y_office_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2014-01-01 to 2017-12-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       48 non-null     float64
#  1   ds      48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.4 KB

# %%
m_office = Prophet()

# %%
m_office.fit(y_office_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_office = m_office.make_future_dataframe(periods=24,freq='MS')

# %%
future_office
# Out:
#            ds
# 0  2014-01-01
# 1  2014-02-01
# 2  2014-03-01
# 3  2014-04-01
# 4  2014-05-01
# ..        ...
# 67 2019-08-01
# 68 2019-09-01
# 69 2019-10-01
# 70 2019-11-01
# 71 2019-12-01
#
# [72 rows x 1 columns]

# %%
forecast_office = m_office.predict(future_office)

# %%
forecast_office
# Out:
#            ds        trend  ...  multiplicative_terms_upper         yhat
# 0  2014-01-01   487.530759  ...                         0.0   347.490278
# 1  2014-02-01   494.918445  ...                         0.0   109.240162
# 2  2014-03-01   501.591193  ...                         0.0   470.211349
# 3  2014-04-01   508.978878  ...                         0.0   374.687188
# 4  2014-05-01   516.128251  ...                         0.0   252.306682
# ..        ...          ...  ...                         ...          ...
# 67 2019-08-01   973.646513  ...                         0.0  1017.522832
# 68 2019-09-01   981.044899  ...                         0.0  1319.326813
# 69 2019-10-01   988.204628  ...                         0.0   799.971727
# 70 2019-11-01   995.603015  ...                         0.0  1396.227478
# 71 2019-12-01  1002.762744  ...                         0.0  1025.758800
#
# [72 rows x 16 columns]

# %%
forecast_office.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast_office[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
#            ds   yhat_lower   yhat_upper         yhat
# 60 2019-01-01   480.266109   874.994891   680.667168
# 61 2019-02-01   449.303568   834.713012   635.972532
# 62 2019-03-01   754.631166  1139.532174   946.732949
# 63 2019-04-01   634.620447  1023.837779   822.147677
# 64 2019-05-01   437.460735   837.156761   628.940592
# 65 2019-06-01   702.274032  1080.905193   884.346368
# 66 2019-07-01   476.582619   872.210621   677.208351
# 67 2019-08-01   819.557023  1217.289109  1017.522832
# 68 2019-09-01  1123.814149  1523.118005  1319.326813
# 69 2019-10-01   607.386503  1004.522148   799.971727
# 70 2019-11-01  1206.118069  1600.825859  1396.227478
# 71 2019-12-01   834.597938  1234.428534  1025.758800

# %%
m_office.plot(forecast_office);
plt.title('Office supplies sales')
plt.xlabel('Years')
plt.ylabel('Sales')
# Out:
# Text(24.725, 0.5, 'Sales')

# %%
plot_plotly(m_office, forecast_office)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id
-11-01T00:00:00", "2014-12-01T00:00:00", "2015-01-01T00:00:00", "2015-02-01T00:00:00", "2015-03-01T00:00:00", "2015-04-01T00:00:00", "2015-05-01T00:00:00", "2015-06-01T00:00:00", "2015-07-01T00:00:00", "2015-08-01T00:00:00", "2015-09-01T00:00:00", "2015-10-01T00:00:00", "2015-11-01T00:00:00", "2015-12-01T00:00:00", "2016-01-01T00:00:00", "2016-02-01T00:00:00", "2016-03-01T00:00:00", "2016-04-01T00:00:00", "2016-05-01T00:00:00", "2016-06-01T00:00:00", "201 ...

# %% [markdown]
# ###### Technology

# %%
y_technology_df = y_technology.to_frame()

# %%
y_technology_df['ds'] = y_technology_df.index

# %%
y_technology_df.columns = ['y','ds']

# %%
y_technology_df
# Out:
#                       y         ds
# Order Date
# 2014-01-01   449.041429 2014-01-01
# 2014-02-01   229.787143 2014-02-01
# 2014-03-01  2031.948375 2014-03-01
# 2014-04-01   613.028933 2014-04-01
# 2014-05-01   564.698588 2014-05-01
# 2014-06-01   766.905909 2014-06-01
# 2014-07-01   533.608933 2014-07-01
# 2014-08-01   708.435385 2014-08-01
# 2014-09-01  2035.838133 2014-09-01
# 2014-10-01   596.900900 2014-10-01
# 2014-11-01  1208.056320 2014-11-01
# 2014-12-01  1160.732889 2014-12-01
# 2015-01-01   925.070800 2015-01-01
# 2015-02-01   431.121250 2015-02-01
# 2015-03-01   574.662333 2015-03-01
# 2015-04-01   697.559500 2015-04-01
# 2015-05-01   831.642857 2015-05-01
# 2015-06-01   429.024400 2015-06-01
# 2015-07-01   691.397733 2015-07-01
# 2015-08-01  1108.902286 2015-08-01
# 2015-09-01   950.856400 2015-09-01
# 2015-10-01   594.716111 2015-10-01
# 2015-11-01  1037.982652 2015-11-01
# 2015-12-01  1619.637636 2015-12-01
# 2016-01-01   374.671067 2016-01-01
# 2016-02-01  1225.891400 2016-02-01
# 2016-03-01  1135.150105 2016-03-01
# 2016-04-01   875.911882 2016-04-01
# 2016-05-01  1601.816167 2016-05-01
# 2016-06-01  1023.259500 2016-06-01
# 2016-07-01   829.312500 2016-07-01
# 2016-08-01   483.620100 2016-08-01
# 2016-09-01  1144.170300 2016-09-01
# 2016-10-01  1970.835875 2016-10-01
# 2016-11-01  1085.642360 2016-11-01
# 2016-12-01   970.554870 2016-12-01
# 2017-01-01  1195.218071 2017-01-01
# 2017-02-01   430.501714 2017-02-01
# 2017-03-01  1392.859250 2017-03-01
# 2017-04-01   825.559133 2017-04-01
# 2017-05-01   678.329400 2017-05-01
# 2017-06-01   853.055000 2017-06-01
# 2017-07-01  1054.996636 2017-07-01
# 2017-08-01   978.842333 2017-08-01
# 2017-09-01  1077.704120 2017-09-01
# 2017-10-01  1493.439227 2017-10-01
# 2017-11-01  1996.750920 2017-11-01
# 2017-12-01   955.865652 2017-12-01

# %%
y_technology_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2014-01-01 to 2017-12-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       48 non-null     float64
#  1   ds      48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB

# %%
m_technology = Prophet()

# %%
m_technology.fit(y_technology_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_technology = m_technology.make_future_dataframe(periods=24,freq='MS')

# %%
future_technology
# Out:
#            ds
# 0  2014-01-01
# 1  2014-02-01
# 2  2014-03-01
# 3  2014-04-01
# 4  2014-05-01
# ..        ...
# 67 2019-08-01
# 68 2019-09-01
# 69 2019-10-01
# 70 2019-11-01
# 71 2019-12-01
#
# [72 rows x 1 columns]

# %%
forecast_technology = m_technology.predict(future_technology)

# %%
forecast_technology
# Out:
#            ds        trend  ...  multiplicative_terms_upper         yhat
# 0  2014-01-01   952.355848  ...                         0.0   731.779926
# 1  2014-02-01   958.476983  ...                         0.0   344.614871
# 2  2014-03-01   964.005750  ...                         0.0  1145.816303
# 3  2014-04-01   970.126885  ...                         0.0   641.603626
# 4  2014-05-01   976.050565  ...                         0.0   738.697628
# ..        ...          ...  ...                         ...          ...
# 67 2019-08-01  1354.771259  ...                         0.0  1490.755922
# 68 2019-09-01  1360.892397  ...                         0.0  1760.154270
# 69 2019-10-01  1366.816079  ...                         0.0   781.501661
# 70 2019-11-01  1372.937217  ...                         0.0  1523.338332
# 71 2019-12-01  1378.860899  ...                         0.0  1790.638983
#
# [72 rows x 16 columns]

# %%
forecast_technology.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast_technology[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
#            ds   yhat_lower   yhat_upper         yhat
# 60 2019-01-01   535.555041  1233.374575   883.346452
# 61 2019-02-01   605.880019  1298.949473   955.920525
# 62 2019-03-01  1086.122668  1781.024141  1438.858819
# 63 2019-04-01   614.579627  1307.033897   991.798219
# 64 2019-05-01   576.838231  1295.809463   955.687693
# 65 2019-06-01   572.633404  1273.805122   924.219609
# 66 2019-07-01   736.064030  1417.940011  1083.824250
# 67 2019-08-01  1128.126804  1839.226333  1490.755922
# 68 2019-09-01  1399.192821  2112.935939  1760.154270
# 69 2019-10-01   437.051613  1126.837476   781.501661
# 70 2019-11-01  1152.237586  1880.322952  1523.338332
# 71 2019-12-01  1448.153609  2150.510562  1790.638983

# %%
m_technology.plot(forecast_technology);
plt.title('Technology supplies sales')
plt.xlabel('Years')
plt.ylabel('Sales')
# Out:
# Text(24.85, 0.5, 'Sales')

# %%
plot_plotly(m_technology, forecast_technology)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ae08c80-2fa6-42f5-9201-9ccc5cbc2a8c" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ae08c80-2fa6-42f5-9201-9ccc5cbc2a8c")) {
#                     Plotly.newPlot(
#                         '1ae08c80-2fa6-42f5-9201-9ccc5cbc2a8c',
